# %%
user_input = input()
# Out:
# oh darling

# %%
title = ''
for x in range(0, len(user_input)):
    if user_input[x] == ' ':
        title = title[:x] + user_input[len(title):x] + '+'
title = title[:x] + user_input[len(title):]
print(title)
# Out:
# oh+darling

# %%
import httplib2
from BeautifulSoup import BeautifulSoup, SoupStrainer

http = httplib2.Http()
status, response = http.request('http://www.nytimes.com')

for link in BeautifulSoup(response, parseOnlyThese=SoupStrainer('a')):
    if link.has_attr('href'):
        print link['href']
        
        
import urllib2

r = urllib2.urlopen('https://www.youtube.com/results?search_query=' + title).read()

soup = BeautifulSoup(r)
# Out:
#   File "<ipython-input-19-2e92e604577a>", line 1
#     from BeautifulSoup import Beautiful Soup
#                                            ^
# SyntaxError: invalid syntax

# %%
from IPython.display import HTML
HTML('https://www.youtube.com/results?search_query=' + title)
# Out:
#   <!DOCTYPE html><html lang="en" data-cast-api-enabled="true"><head><style name="www-roboto">@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v15/RxZJdnzeo3R5zSexge8UUaCWcynf_cDxXwCLxiixG1c.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v15/zN7GBFwfMP4uA6AR0HCoLQ.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v15/OLffGBTaF0XFOW1gnuHF0Z0EAVxt0G0biEntp43Qt6E.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v15/W4wDsBUluyw0tK3tykhXEfesZW2xOQ-xsNqO47m55DA.ttf)format('truetype');}</style><script name="www-r
# ...

# %%
videos = soup.find_all('a')

# %%
videos[0]

# %%
links = {}
for element in videos:
    element
print element.get_link()
#for element in videos:
 #   links[element.a.get_text()] = {}

# %%
links[0].a['href="/watch']

# %%
youtube_code = 'vWaRiD5ym74'

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(youtube_code)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/vWaRiD5ym74"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
